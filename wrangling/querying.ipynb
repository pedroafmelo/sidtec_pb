# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", 61)

# %%
dados = pd.read_csv("dbt_2020.csv", encoding = "UTF-8")

# %%
dados
# Out:
#       AN_BASE    CD_PROGRAMA                        NM_PROGRAMA  \
# 0        2020  24001015016P1                         ENFERMAGEM
# 1        2020  24001015016P1                         ENFERMAGEM
# 2        2020  24001015016P1                         ENFERMAGEM
# 3        2020  24001015016P1                         ENFERMAGEM
# 4        2020  24001015016P1                         ENFERMAGEM
# ...       ...            ...                                ...
# 1999     2020  24009016030P5  CIÊNCIAS NATURAIS E BIOTECNOLOGIA
# 2000     2020  24009016030P5  CIÊNCIAS NATURAIS E BIOTECNOLOGIA
# 2001     2020  24009016030P5  CIÊNCIAS NATURAIS E BIOTECNOLOGIA
# 2002     2020  24009016030P5  CIÊNCIAS NATURAIS E BIOTECNOLOGIA
# 2003     2020  24009016030P5  CIÊNCIAS NATURAIS E BIOTECNOLOGIA
#
#      SG_ENTIDADE_ENSINO                               NM_ENTIDADE_ENSINO  \
# 0               UFPB-JP  UNIVERSIDADE FEDERAL DA PARAÍBA ( JOÃO PESSOA )
# ...

# %%
dados.info()

# %%
dados["DH_INICIO_AREA_CONC"] = dados["DH_INICIO_AREA_CONC"]

# %%
string = dados["DH_INICIO_AREA_CONC"][0]

replacements = {"JUN": "-01-"}

replaced = [replacements.get(char, char) for char in string]

# %%
replaced
# Out:
# ['2',
#  '9',
#  'J',
#  'U',
#  'N',
#  '2',
#  '0',
#  '1',
#  '1',
#  ':',
#  '0',
#  '0',
#  ':',
#  '0',
#  '0',
#  ':',
#  '0',
#  '0']

# %%
dados.to_excel("dbt_excel_2020.xlsx", encoding = "UTF-8", index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/pedroafmelo/Documents/projetos/sidtec-pb/wrangling/querying.ipynb Célula 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/pedroafmelo/Documents/projetos/sidtec-pb/wrangling/querying.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> dados.to_excel("dbt_excel_2020.xlsx", encoding = "UTF-8", index = False)
#
# TypeError: NDFrame.to_excel() got an unexpected keyword argument 'encoding'

# %%
data = pd.read_excel("/Users/pedroafmelo/Documents/projetos/sidtec-pb/wrangling/br-capes-btd-2017a2020-2021-12-03_2020.xlsx").query("NM_UF_IES == 'PARAÍBA'")
data.to_excel("dbt_excel_2020.xlsx", index = False)
