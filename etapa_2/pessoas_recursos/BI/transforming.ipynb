# %%
import pandas as pd

# %%
bolsas_posgrad_capes_br_1995a2022 = "/Volumes/SEAGATE_EHD/sidtec_pb/pesquisa/drive_sid/bolsas_pos_graduacao_capes_brasil_1995-2022.xlsx"
bolsas_posgrad_capes_pb_1995a2022 = "/Volumes/SEAGATE_EHD/sidtec_pb/pesquisa/drive_sid/bolsas_pos_graduacao_capes_pb_1995-2022.xlsx"
cnpq_mes_doc_br_2005a2023 = "/Volumes/SEAGATE_EHD/sidtec_pb/pesquisa/drive_sid/cnpq_mestrado_doutorado_brasil_2005-2023.xlsx"
cnpq_ppq_br_2005a2023 = "/Volumes/SEAGATE_EHD/sidtec_pb/pesquisa/drive_sid/cnpq_produtividade_pesquisa_brasil_2005-2023.xlsx"
orcamento_uni = "/Volumes/SEAGATE_EHD/sidtec_pb/pesquisa/drive_sid/orçamento_universidades_2000_2023.xlsx"

# %%
bolsas_posgrad_capes_br_1995a2022 = pd.read_excel(bolsas_posgrad_capes_br_1995a2022)
bolsas_posgrad_capes_pb_1995a2022 = pd.read_excel(bolsas_posgrad_capes_pb_1995a2022)
cnpq_mes_doc_br_2005a2023 = pd.read_excel(cnpq_mes_doc_br_2005a2023)
cnpq_ppq_br_2005a2023 = pd.read_excel(cnpq_ppq_br_2005a2023)
# orcamento_uni = pd.read_excel(orcamento_uni)

bolsas_posgrad_capes_br_1995a2022 = bolsas_posgrad_capes_br_1995a2022.query("ANO >= 2005 and ANO <= 2022")
bolsas_posgrad_capes_br_1995a2022 = bolsas_posgrad_capes_br_1995a2022.sort_values(by = "ANO")
bolsas_posgrad_capes_pb_1995a2022 = bolsas_posgrad_capes_pb_1995a2022.query("ANO >= 2005 and ANO <= 2022")
bolsas_posgrad_capes_pb_1995a2022 = bolsas_posgrad_capes_pb_1995a2022.sort_values(by = "ANO")
cnpq_mes_doc_br_2005a2023 = cnpq_mes_doc_br_2005a2023.query("ANO >= 2005 and ANO <= 2022")
cnpq_mes_doc_br_2005a2023 = cnpq_mes_doc_br_2005a2023.sort_values(by = "ANO")
cnpq_ppq_br_2005a2023 = cnpq_ppq_br_2005a2023.query("ANO >= 2005 and ANO <= 2022")
cnpq_ppq_br_2005a2023 = cnpq_ppq_br_2005a2023.sort_values(by = "ANO")
# orcamento_uni = orcamento_uni.query("ANO >= 2005 and ANO <= 2022")

# %%
dict_grande_area = {"MULTIDISCIPLINAR": "CTI", "CIÊNCIAS AGRÁRIAS": "CTI", "CIÊNCIAS SOCIAIS APLICADAS": "OUTRAS",
                    "CIÊNCIAS EXATAS E DA TERRA": "CTI", "CIÊNCIAS DA SAÚDE": "CTI", "Grande Area Não Informada": "OUTRAS",
                    "CIÊNCIAS BIOLÓGICAS": "CTI", "ENGENHARIAS": "CTI", "CIÊNCIAS HUMANAS": "OUTRAS", 
                    "LINGÜÍSTICA, LETRAS E ARTES": "OUTRAS"}

# %%
lista_anos = list(range(2005, 2023))

# %%
população = "/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/POPULAÇÃO_1995A2022.xlsx"

populacao = pd.read_excel(população, dtype = int).query("ANO >= 2005")

populacao.head(3)

lista_pop_br = list(populacao["POP_BR"])
lista_pop_ne = list(populacao["POP_NE"])
lista_pop_pb = list(populacao["POP_PB"])

lista_pop_br_10k = []
lista_pop_ne_10k = []
lista_pop_pb_10k = []

lista_pop_br_100k = []
lista_pop_ne_100k = []
lista_pop_pb_100k = []

for num in lista_pop_br:
    lista_pop_br_10k.append(num / 10000)
    lista_pop_br_100k.append(num/100000)

for num in lista_pop_ne:
    lista_pop_ne_10k.append(num / 10000)
    lista_pop_ne_100k.append(num/100000)

for num in lista_pop_pb:
    lista_pop_pb_10k.append(num / 10000)
    lista_pop_pb_100k.append(num/100000)

# %% [markdown]
# # BOLSAS CAPES BR

# %%
bolsas_posgrad_capes_br_1995a2022.head(3)
# Out:
#               REGIAO IDUF  NOMEMUNICIPIO  CD_MUNICIPIO_IBGE   ANO  \
# 140290           SUL   SC  FLORIANÓPOLIS            4205407  2005
# 137132       SUDESTE   SP     SÃO CARLOS            3548906  2005
# 137133  CENTRO-OESTE   DF       BRASÍLIA            5300108  2005
#
#        STATUSJURIDICO     IES            NIVEL                 GRANDEAREA  \
# 140290        Federal    UFSC    PÓS-DOUTORADO           CIÊNCIAS HUMANAS
# 137132       Estadual  USP/SC         MESTRADO  Grande Area Não Informada
# 137133        Federal     UNB  DOUTORADO PLENO           CIÊNCIAS HUMANAS
#
#           AREACONHECIMENTO               AREAAVALIACAO         NOMEPROGRAMA  \
# 140290        ANTROPOLOGIA  ANTROPOLOGIA / ARQUEOLOGIA  ANTROPOLOGIA SOCIAL
# 137132  Área Não Informada                  INDEFINIDA                  NaN
# 137133            HISTÓRIA                    HISTÓRIA             HISTÓRIA
#
#         REFERENCIAL
# 140290            1
# 137132            7
# 137133            7

# %%
bolsas_posgrad_capes_br_1995a2022["CTI"] = bolsas_posgrad_capes_br_1995a2022["GRANDEAREA"].map(dict_grande_area)
bolsas_posgrad_capes_br_1995a2022.head(5)
# Out:
#               REGIAO IDUF  NOMEMUNICIPIO  CD_MUNICIPIO_IBGE   ANO  \
# 140290           SUL   SC  FLORIANÓPOLIS            4205407  2005
# 137132       SUDESTE   SP     SÃO CARLOS            3548906  2005
# 137133  CENTRO-OESTE   DF       BRASÍLIA            5300108  2005
# 137134       SUDESTE   SP       CAMPINAS            3509502  2005
# 137135           SUL   PR       CURITIBA            4106902  2005
#
#        STATUSJURIDICO      IES            NIVEL                 GRANDEAREA  \
# 140290        Federal     UFSC    PÓS-DOUTORADO           CIÊNCIAS HUMANAS
# 137132       Estadual   USP/SC         MESTRADO  Grande Area Não Informada
# 137133        Federal      UNB  DOUTORADO PLENO           CIÊNCIAS HUMANAS
# 137134       Estadual  UNICAMP         MESTRADO          CIÊNCIAS AGRÁRIAS
# 137135        Federal     UFPR  DOUTORADO PLENO        CIÊNCIAS BIOLÓGICAS
#
#                          AREACONHECIMENTO               AREAAVALIACAO  \
# ...

# %%
bolsas_posgrad_capes_br_1995a2022.query("ANO == 2005 and CTI == 'CTI'")["REFERENCIAL"].sum()
# Out:
# 18319

# %%
lista_CTI_br = []
for i in range(min(list(bolsas_posgrad_capes_br_1995a2022["ANO"].unique())), 
               max(list(bolsas_posgrad_capes_br_1995a2022["ANO"].unique())) + 1):
    dados = bolsas_posgrad_capes_br_1995a2022.query(f"ANO == {i}")
    dados = dados.query("CTI == 'CTI'")
    total = dados["REFERENCIAL"].sum()
    lista_CTI_br.append(total)

lista_outras_br = []
for i in range(min(list(bolsas_posgrad_capes_br_1995a2022["ANO"].unique())), 
               max(list(bolsas_posgrad_capes_br_1995a2022["ANO"].unique())) + 1):
    dados = bolsas_posgrad_capes_br_1995a2022.query(f"ANO == {i}")
    dados = dados.query("CTI == 'OUTRAS'")
    total = dados["REFERENCIAL"].sum()
    lista_outras_br.append(total)

# %%
lista_CTI_br
# Out:
# [18319,
#  20951,
#  21014,
#  27861,
#  32923,
#  40891,
#  51615,
#  55680,
#  60340,
#  63777,
#  66649,
#  64913,
#  67037,
#  67131,
#  63548,
#  67177,
#  65646,
#  65221]

# %%
bolsas_posgrad_capes_br_1995a2022.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/capes_br.xlsx", index = False)

# %% [markdown]
# # BOLSAS CAPES PB

# %%
bolsas_posgrad_capes_pb_1995a2022.head(3)
# Out:
#      REGIAO IDUF   NOMEMUNICIPIO  CD_MUNICIPIO_IBGE   ANO STATUSJURIDICO  \
# 0  NORDESTE   PB           AREIA            2501104  2022        Federal
# 1  NORDESTE   PB  CAMPINA GRANDE            2504009  2022        Federal
# 2  NORDESTE   PB           AREIA            2501104  2022        Federal
#
#           IES            NIVEL         GRANDEAREA     AREACONHECIMENTO  \
# 0  UFPB/AREIA  DOUTORADO PLENO  CIÊNCIAS AGRÁRIAS            AGRONOMIA
# 1        UFCG  DOUTORADO PLENO  CIÊNCIAS AGRÁRIAS  ENGENHARIA AGRÍCOLA
# 2  UFPB/AREIA         MESTRADO  CIÊNCIAS AGRÁRIAS            AGRONOMIA
#
#          AREAAVALIACAO         NOMEPROGRAMA  REFERENCIAL
# 0  CIÊNCIAS AGRÁRIAS I            AGRONOMIA           61
# 1  CIÊNCIAS AGRÁRIAS I  ENGENHARIA AGRÍCOLA           46
# 2  CIÊNCIAS AGRÁRIAS I            AGRONOMIA           40

# %%
bolsas_posgrad_capes_pb_1995a2022["CTI"] = bolsas_posgrad_capes_pb_1995a2022["GRANDEAREA"].map(dict_grande_area)
bolsas_posgrad_capes_pb_1995a2022.head(5)
# Out:
#         REGIAO IDUF   NOMEMUNICIPIO  CD_MUNICIPIO_IBGE   ANO STATUSJURIDICO  \
# 3868  NORDESTE   PB  CAMPINA GRANDE            2504009  2005        Federal
# 3771  NORDESTE   PB  CAMPINA GRANDE            2504009  2005        Federal
# 3770  NORDESTE   PB     JOÃO PESSOA            2507507  2005        Federal
# 3769  NORDESTE   PB  CAMPINA GRANDE            2504009  2005        Federal
# 3768  NORDESTE   PB     JOÃO PESSOA            2507507  2005        Federal
#
#             IES            NIVEL                  GRANDEAREA  \
# 3868       UFCG  DOUTORADO PLENO                 ENGENHARIAS
# 3771       UFCG         MESTRADO           CIÊNCIAS AGRÁRIAS
# 3770  UFPB/J.P.  DOUTORADO PLENO   Grande Area Não Informada
# 3769       UFCG  DOUTORADO PLENO  CIÊNCIAS EXATAS E DA TERRA
# 3768  UFPB/J.P.         MESTRADO           CIÊNCIAS DA SAÚDE
#
#           AREACONHECIMENTO                             AREAAVALIACAO  \
# ...

# %%
bolsas_posgrad_capes_pb_1995a2022.query("ANO == 2005 and CTI == 'CTI'")["REFERENCIAL"].sum()
# Out:
# 467

# %%
lista_CTI_pb = []
for i in range(min(list(bolsas_posgrad_capes_pb_1995a2022["ANO"].unique())), max(list(bolsas_posgrad_capes_pb_1995a2022["ANO"].unique())) + 1):
    dados = bolsas_posgrad_capes_pb_1995a2022.query(f"ANO == {i}")
    dados = dados.query("CTI == 'CTI'")
    total = dados["REFERENCIAL"].sum()
    lista_CTI_pb.append(total)

lista_outras_pb = []
for i in range(min(list(bolsas_posgrad_capes_pb_1995a2022["ANO"].unique())), max(list(bolsas_posgrad_capes_pb_1995a2022["ANO"].unique())) + 1):
    dados = bolsas_posgrad_capes_pb_1995a2022.query(f"ANO == {i}")
    dados = dados.query("CTI == 'OUTRAS'")
    total = dados["REFERENCIAL"].sum()
    lista_outras_pb.append(total)

# %%
lista_CTI_pb
# Out:
# [467,
#  511,
#  542,
#  761,
#  1124,
#  1453,
#  1860,
#  1938,
#  1921,
#  1909,
#  1936,
#  1891,
#  2059,
#  2107,
#  1958,
#  1827,
#  1705,
#  1566]

# %%
bolsas_posgrad_capes_pb_1995a2022.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/capes_pb.xlsx", index = False)

# %% [markdown]
# # BOLSAS CAPES NORDESTE

# %%
bolsas_posgrad_capes_ne_1995a2022 = pd.read_excel("/Volumes/SEAGATE_EHD/sidtec_pb/pesquisa/drive_sid/bolsas_pos_graduacao_capes_brasil_1995-2022.xlsx")
bolsas_posgrad_capes_ne_1995a2022 = bolsas_posgrad_capes_ne_1995a2022.query("REGIAO == 'NORDESTE'")
bolsas_posgrad_capes_ne_1995a2022 = bolsas_posgrad_capes_ne_1995a2022.query("ANO >= 2005 and ANO <= 2022")
bolsas_posgrad_capes_ne_1995a2022 = bolsas_posgrad_capes_ne_1995a2022.sort_values(by = "ANO")

bolsas_posgrad_capes_ne_1995a2022.index = range(bolsas_posgrad_capes_ne_1995a2022.shape[0])

bolsas_posgrad_capes_ne_1995a2022.head(3)
# Out:
#      REGIAO IDUF  NOMEMUNICIPIO  CD_MUNICIPIO_IBGE   ANO STATUSJURIDICO  \
# 0  NORDESTE   SE  SÃO CRISTÓVÃO            2806701  2005        Federal
# 1  NORDESTE   RN          NATAL            2408102  2005        Federal
# 2  NORDESTE   CE      FORTALEZA            2304400  2005        Federal
#
#      IES            NIVEL         GRANDEAREA           AREACONHECIMENTO  \
# 0  FUFSE  DOUTORADO PLENO   CIÊNCIAS HUMANAS           CIÊNCIA POLÍTICA
# 1   UFRN         MESTRADO  CIÊNCIAS DA SAÚDE                   NUTRIÇÃO
# 2    UFC         MESTRADO  CIÊNCIAS DA SAÚDE  GINECOLOGIA E OBSTETRÍCIA
#
#                                 AREAAVALIACAO       NOMEPROGRAMA  REFERENCIAL
# 0  CIÊNCIA POLÍTICA E RELAÇÕES INTERNACIONAIS  CIÊNCIA  POLÍTICA            1
# 1                                 MEDICINA II  CIÊNCIAS DA SAÚDE            4
# 2                                MEDICINA III   TOCO-GINECOLOGIA            4

# %%
bolsas_posgrad_capes_ne_1995a2022["CTI"] = bolsas_posgrad_capes_ne_1995a2022["GRANDEAREA"].map(dict_grande_area)
bolsas_posgrad_capes_ne_1995a2022.head(5)
# Out:
#      REGIAO IDUF  NOMEMUNICIPIO  CD_MUNICIPIO_IBGE   ANO STATUSJURIDICO  \
# 0  NORDESTE   SE  SÃO CRISTÓVÃO            2806701  2005        Federal
# 1  NORDESTE   RN          NATAL            2408102  2005        Federal
# 2  NORDESTE   CE      FORTALEZA            2304400  2005        Federal
# 3  NORDESTE   RN        MOSSORÓ            2408003  2005       Estadual
# 4  NORDESTE   CE      FORTALEZA            2304400  2005        Federal
#
#      IES            NIVEL         GRANDEAREA           AREACONHECIMENTO  \
# 0  FUFSE  DOUTORADO PLENO   CIÊNCIAS HUMANAS           CIÊNCIA POLÍTICA
# 1   UFRN         MESTRADO  CIÊNCIAS DA SAÚDE                   NUTRIÇÃO
# 2    UFC         MESTRADO  CIÊNCIAS DA SAÚDE  GINECOLOGIA E OBSTETRÍCIA
# 3   UERN         MESTRADO   MULTIDISCIPLINAR           INTERDISCIPLINAR
# 4    UFC         MESTRADO  CIÊNCIAS AGRÁRIAS            CIÊNCIA DO SOLO
#
#                                 AREAAVALIACAO  \
# 0  CIÊNCIA POLÍTICA E RELAÇÕES INTERNACIONAIS
# ...

# %%
bolsas_posgrad_capes_ne_1995a2022.query("ANO == 2005 and CTI == 'CTI'")["REFERENCIAL"].sum()
# Out:
# 2507

# %%
lista_CTI_ne = []
for i in range(min(list(bolsas_posgrad_capes_ne_1995a2022["ANO"].unique())), max(list(bolsas_posgrad_capes_ne_1995a2022["ANO"].unique())) + 1):
    dados = bolsas_posgrad_capes_ne_1995a2022.query(f"ANO == {i}")
    dados = dados.query("CTI == 'CTI'")
    total = dados["REFERENCIAL"].sum()
    lista_CTI_ne.append(total)

lista_outras_ne = []
for i in range(min(list(bolsas_posgrad_capes_ne_1995a2022["ANO"].unique())), max(list(bolsas_posgrad_capes_ne_1995a2022["ANO"].unique())) + 1):
    dados = bolsas_posgrad_capes_ne_1995a2022.query(f"ANO == {i}")
    dados = dados.query("CTI == 'OUTRAS'")
    total = dados["REFERENCIAL"].sum()
    lista_outras_ne.append(total)

# %%
lista_CTI_ne
# Out:
# [2507,
#  3192,
#  3370,
#  4615,
#  6352,
#  8095,
#  10392,
#  11069,
#  11479,
#  11668,
#  11999,
#  11607,
#  12183,
#  12103,
#  11421,
#  11621,
#  11717,
#  12073]

# %% [markdown]
# # BOLSAS CNPQ MESTRADO E DOUTORADO

# %%
cnpq_mes_doc_br_2005a2023.head(3)
# Out:
#                                     INSTITUICAO  \
# 0     Aalto University School of Art and Design
# 7148     Universidade Federal de Santa Catarina
# 7149     Universidade Federal de Santa Catarina
#
#                                        AREACONHECIMENTO  \
# 0     PROGRAMA DE ACAO INDUZIDA PARA FORMACAO NO EXT...
# 7148                                Programas Regulares
# 7149                                Programas Regulares
#
#                       NIVEL CATEGORIA_NIVEL                  GRANDEAREA  \
# 0     Doutorado no Exterior             NaN  Ciências Sociais Aplicadas
# 7148          Pós-Doutorado             NaN  Ciências Exatas e da Terra
# 7149          Pós-Doutorado             NaN  Ciências Exatas e da Terra
#
#                               LINHAFORMENTO ORIGEMRECURSO    REGIAO IDUF  \
# 0     BOLSAS DE FORMAÇÃO E DE PESQUISADORES          CNPq  Exterior  \EX
# 7148  BOLSAS DE FORMAÇÃO E DE PESQUISADORES          CNPq       Sul   SC
# ...

# %%
cnpq_mes_doc_br_2005a2023["NIVEL"].unique()
# Out:
# array(['Doutorado no Exterior', 'Pós-Doutorado', 'Doutorado', 'Mestrado',
#        'Doutorado Sanduíche', 'Fixação de Doutores/Recém-Doutor',
#        'Doutorado Sanduíche no Exterior', 'Pós-Doutorado Exterior',
#        'Pós-Doutorado Empresarial', 'Doutorado Sanduíche Empresarial',
#        'Mestrado Profissional no Exterior'], dtype=object)

# %%
cnpq_mes_doc_br_2005a2023.query(r"IDUF == '\\NI'")
# Out:
#          INSTITUICAO     AREACONHECIMENTO          NIVEL CATEGORIA_NIVEL  \
# 11786  Não informada  Programas Regulares  Pós-Doutorado             NaN
# 22998  Não informada  Programas Regulares  Pós-Doutorado             NaN
#
#                         GRANDEAREA                          LINHAFORMENTO  \
# 11786  Lingüística, Letras e Artes  BOLSAS DE FORMAÇÃO E DE PESQUISADORES
# 22998  Lingüística, Letras e Artes  BOLSAS DE FORMAÇÃO E DE PESQUISADORES
#
#       ORIGEMRECURSO         REGIAO IDUF  NOMEMUNICIPIO  CD_MUNICIPIO_IBGE  \
# 11786          CNPq  Não informada  \NI  Não informada                NaN
# 22998          CNPq  Não informada  \NI  Não informada                NaN
#
#        BENEFICIARIO_ANO  BOLSA_ANO  AUXILIO_ANO   ANO
# 11786               1.0       0.25            0  2006
# 22998               1.0       0.75            0  2007

# %%
lista_mes_doc_cnpq_br = []
for i in range(min(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())), max(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())) + 1):
    dados = cnpq_mes_doc_br_2005a2023.query(f"ANO == {i} and REGIAO != 'Exterior'")
    lista_mes_doc_cnpq_br.append(dados.shape[0])

lista_mes_doc_cnpq_ne = []
for i in range(min(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())), max(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())) + 1):
    dados = cnpq_mes_doc_br_2005a2023.query(f"ANO == {i} and REGIAO == 'Nordeste'")
    lista_mes_doc_cnpq_ne.append(dados.shape[0])

lista_mes_doc_cnpq_pb = []
for i in range(min(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())), max(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())) + 1):
    dados = cnpq_mes_doc_br_2005a2023.query(f"ANO == {i} and IDUF == 'PB'")
    lista_mes_doc_cnpq_pb.append(dados.shape[0])

# %% [markdown]
# # BOLSAS CNPQ PPQ

# %%
cnpq_ppq_br_2005a2023.head(3)
# Out:
#                                  INSTITUICAO     AREACONHECIMENTO  \
# 0                           Arquivo Nacional  Programas Regulares
# 5766  Universidade Federal de Santa Catarina  Programas Regulares
# 5765  Universidade Federal de Santa Catarina  Programas Regulares
#
#                           NIVEL CATEGORIA_NIVEL                   GRANDEAREA  \
# 0     Produtividade em Pesquisa              1C  Lingüística, Letras e Artes
# 5766  Produtividade em Pesquisa              1D                  Engenharias
# 5765  Produtividade em Pesquisa              1D                  Engenharias
#
#                               LINHAFORMENTO ORIGEMRECURSO   REGIAO IDUF  \
# 0     BOLSAS DE FORMAÇÃO E DE PESQUISADORES          CNPq  Sudeste   RJ
# 5766  BOLSAS DE FORMAÇÃO E DE PESQUISADORES          CNPq      Sul   SC
# 5765  BOLSAS DE FORMAÇÃO E DE PESQUISADORES          CNPq      Sul   SC
#
#        NOMEMUNICIPIO  CD_MUNICIPIO_IBGE  BENEFICIARIO_ANO  BOLSA_ANO  \
# ...

# %%
cnpq_ppq_br_2005a2023["REGIAO"].unique()
# Out:
# array(['Sudeste', 'Sul', 'Nordeste', 'Norte', 'Centro-Oeste'],
#       dtype=object)

# %%
lista_pq_cnpq_br = []
for i in range(min(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())), max(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())) + 1):
    dados = cnpq_ppq_br_2005a2023.query(f"ANO == {i} and REGIAO != 'Exterior'")
    lista_pq_cnpq_br.append(dados.shape[0])

lista_pq_cnpq_ne = []
for i in range(min(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())), max(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())) + 1):
    dados = cnpq_ppq_br_2005a2023.query(f"ANO == {i} and REGIAO == 'Nordeste'")
    lista_pq_cnpq_ne.append(dados.shape[0])

lista_pq_cnpq_pb = []
for i in range(min(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())), max(list(cnpq_mes_doc_br_2005a2023["ANO"].unique())) + 1):
    dados = cnpq_ppq_br_2005a2023.query(f"ANO == {i} and IDUF == 'PB'")
    lista_pq_cnpq_pb.append(dados.shape[0])

# %%
dados = pd.read_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/new_data.xlsx")

dados.columns
# Out:
# Index(['ANO', 'POP_BR', 'POP_BR_10K', 'POP_BR_100K', 'POP_PB', 'POP_PB_10K',
#        'POP_PB_100K', 'POP_NE', 'POP_NE_10K', 'POP_NE_100K', 'CAPES_CTI_BR',
#        'CAPES_OUTRAS_BR', 'CAPES_CTI_PB', 'CAPES_OUTRAS_PB', 'CAPES_CTI_NE',
#        'CAPES_OUTRAS_NE', 'CNPQ_MES_DOC_BR', 'CNPQ_MES_DOC_PB',
#        'CNPQ_MES_DOC_NE', 'CNPQ_PQ_BR', 'CNPQ_PQ_PB', 'CNPQ_PQ_NE',
#        'cti/outras_br', 'cti/outras_pb', 'cti/outras_ne'],
#       dtype='object')

# %%
colunas_br = ['ANO', 'POP_BR', 'POP_BR_10K', 'POP_BR_100K', 'POP_PB', 'POP_PB_10K',
       'POP_PB_100K', 'POP_NE', 'POP_NE_10K', 'POP_NE_100K', 'CAPES_CTI_BR',
       'CAPES_OUTRAS_BR', 'CNPQ_MES_DOC_BR', 'CNPQ_PQ_BR']

colunas_pb = ['ANO', 'POP_BR', 'POP_BR_10K', 'POP_BR_100K', 'POP_PB', 'POP_PB_10K',
       'POP_PB_100K', 'POP_NE', 'POP_NE_10K', 'POP_NE_100K', 'CAPES_CTI_PB', 'CAPES_OUTRAS_PB',
       'CNPQ_MES_DOC_PB', 'CNPQ_PQ_PB']

colunas_ne = ['ANO', 'POP_BR', 'POP_BR_10K', 'POP_BR_100K', 'POP_PB', 'POP_PB_10K',
       'POP_PB_100K', 'POP_NE', 'POP_NE_10K', 'POP_NE_100K', 'CAPES_CTI_NE',
       'CAPES_OUTRAS_NE','CNPQ_MES_DOC_NE', 'CNPQ_PQ_NE']

# %%
dados["cti/outras_br"] = dados["CAPES_CTI_BR"] / dados["CAPES_OUTRAS_BR"]
dados["cti/outras_pb"] = dados["CAPES_CTI_PB"] / dados["CAPES_OUTRAS_PB"]
dados["cti/outras_ne"] = dados["CAPES_CTI_NE"] / dados["CAPES_OUTRAS_NE"]

# %%
dados.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/new_data.xlsx", index = False)

# %% [markdown]
# # APLICAÇÃO AJUSTES

# %%
bolsas_posgrad_capes_br_1995a2022.groupby(by = ["GRANDEAREA"])["REFERENCIAL"].sum().to_frame()
# Out:
#                              REFERENCIAL
# GRANDEAREA
# CIÊNCIAS AGRÁRIAS                 179024
# CIÊNCIAS BIOLÓGICAS               137643
# CIÊNCIAS DA SAÚDE                 189234
# CIÊNCIAS EXATAS E DA TERRA        151810
# CIÊNCIAS HUMANAS                  192023
# CIÊNCIAS SOCIAIS APLICADAS        111987
# ENGENHARIAS                       144907
# Grande Area Não Informada          78349
# LINGÜÍSTICA, LETRAS E ARTES        70614
# MULTIDISCIPLINAR                  118075

# %%
total_grande_area_br = bolsas_posgrad_capes_br_1995a2022.groupby(by = ["GRANDEAREA"])["REFERENCIAL"].sum().to_frame()
total_grande_area_pb = bolsas_posgrad_capes_pb_1995a2022.groupby(by = ["GRANDEAREA"])["REFERENCIAL"].sum().to_frame()
total_grande_area_ne = bolsas_posgrad_capes_ne_1995a2022.groupby(by = ["GRANDEAREA"])["REFERENCIAL"].sum().to_frame()

total_grande_area_br_df = bolsas_posgrad_capes_br_1995a2022.groupby(by = ["ANO", "GRANDEAREA"])["REFERENCIAL"].sum().to_frame()
total_grande_area_pb_df = bolsas_posgrad_capes_pb_1995a2022.groupby(by = ["ANO", "GRANDEAREA"])["REFERENCIAL"].sum().to_frame()
total_grande_area_ne_df = bolsas_posgrad_capes_ne_1995a2022.groupby(by = ["ANO", "GRANDEAREA"])["REFERENCIAL"].sum().to_frame()

total_grande_area_br.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/grande_area_br.xlsx")
total_grande_area_ne.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/grande_area_ne.xlsx")
total_grande_area_pb.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/grande_area_pb.xlsx")

total_grande_area_br_df.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/grande_area_br_df.xlsx")
total_grande_area_ne_df.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/grande_area_ne_df.xlsx")
total_grande_area_pb_df.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/grande_area_pb_df.xlsx")

# %%
dados["bolsas/pop10_BR"] = dados["CAPES_CTI_BR"] / dados["POP_BR_10K"]
dados["bolsas/pop10_PB"] = dados["CAPES_CTI_PB"] / dados["POP_PB_10K"]
dados["bolsas/pop10_NE"] = dados["CAPES_CTI_NE"] / dados["POP_NE_10K"]

dados["bolsas/pop100_BR"] = dados["CAPES_CTI_BR"] / dados["POP_BR_100K"]
dados["bolsas/pop100_PB"] = dados["CAPES_CTI_PB"] / dados["POP_PB_100K"]
dados["bolsas/pop100_NE"] = dados["CAPES_CTI_NE"] / dados["POP_NE_100K"]

dados
# Out:
#      ANO     POP_BR  POP_BR_10K  POP_BR_100K   POP_PB  POP_PB_10K  \
# 0   2005  180173245  18017.3245   1801.73245  3602935    360.2935
# 1   2006  182289756  18228.9756   1822.89756  3635654    363.5654
# 2   2007  184406267  18440.6267   1844.06267  3668372    366.8372
# 3   2008  186522777  18652.2777   1865.22777  3701091    370.1091
# 4   2009  188639288  18863.9288   1886.39288  3733809    373.3809
# 5   2010  190755799  19075.5799   1907.55799  3766527    376.6527
# 6   2011  191781358  19178.1358   1917.81358  3783874    378.3874
# 7   2012  192806917  19280.6917   1928.06917  3801221    380.1221
# 8   2013  193832477  19383.2477   1938.32477  3818567    381.8567
# 9   2014  194858036  19485.8036   1948.58036  3835914    383.5914
# 10  2015  195883596  19588.3596   1958.83596  3853260    385.3260
# 11  2016  196909155  19690.9155   1969.09155  3870607    387.0607
# 12  2017  197934714  19793.4714   1979.34714  3887954    388.7954
# ...

# %%
dados.columns
# Out:
# Index(['ANO', 'POP_BR', 'POP_BR_10K', 'POP_BR_100K', 'POP_PB', 'POP_PB_10K',
#        'POP_PB_100K', 'POP_NE', 'POP_NE_10K', 'POP_NE_100K', 'CAPES_CTI_BR',
#        'CAPES_OUTRAS_BR', 'CAPES_CTI_PB', 'CAPES_OUTRAS_PB', 'CAPES_CTI_NE',
#        'CAPES_OUTRAS_NE', 'CNPQ_MES_DOC_BR', 'CNPQ_MES_DOC_PB',
#        'CNPQ_MES_DOC_NE', 'CNPQ_PQ_BR', 'CNPQ_PQ_PB', 'CNPQ_PQ_NE',
#        'cti/outras_br', 'cti/outras_pb', 'cti/outras_ne', 'bolsas/pop10_BR',
#        'bolsas/pop10_PB', 'bolsas/pop10_NE', 'bolsas/pop100_BR',
#        'bolsas/pop100_PB', 'bolsas/pop100_NE', 'bolsas_pq/pop10_br',
#        'bolsas_pq/pop10_pb', 'bolsas_pq/pop10_ne', 'bolsas_pq/pop100_br',
#        'bolsas_pq/pop100_pb', 'bolsas_pq/pop100_ne'],
#       dtype='object')

# %%
dados.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/new_data.xlsx", index = False)

# %%
dados["bolsas_pq/pop10_br"] = dados["CNPQ_PQ_BR"] / dados["POP_BR_10K"]
dados["bolsas_pq/pop10_pb"]= dados["CNPQ_PQ_PB"] / dados["POP_PB_10K"]
dados["bolsas_pq/pop10_ne"] = dados["CNPQ_PQ_NE"] / dados["POP_NE_10K"]

dados["bolsas_pq/pop100_br"] = dados["CNPQ_PQ_BR"] / dados["POP_BR_100K"]
dados["bolsas_pq/pop100_pb"] = dados["CNPQ_PQ_PB"] / dados["POP_PB_100K"]
dados["bolsas_pq/pop100_ne"] = dados["CNPQ_PQ_NE"] / dados["POP_NE_100K"]

dados["bolsas_md/pop10_br"] = dados["CNPQ_MES_DOC_BR"] / dados["POP_BR_10K"]
dados["bolsas_md/pop10_pb"]= dados["CNPQ_MES_DOC_BR"] / dados["POP_PB_10K"]
dados["bolsas_md/pop10_ne"] = dados["CNPQ_MES_DOC_BR"] / dados["POP_NE_10K"]

dados["bolsas_md/pop100_br"] = dados["CNPQ_MES_DOC_BR"] / dados["POP_BR_100K"]
dados["bolsas_md/pop100_pb"] = dados["CNPQ_MES_DOC_BR"] / dados["POP_PB_100K"]
dados["bolsas_md/pop100_ne"] = dados["CNPQ_MES_DOC_BR"] / dados["POP_NE_100K"]

dados.to_excel("/Users/pedroafmelo/Documents/projetos/sidtec_pb/etapa_2/pessoas_recursos/dados/new_data.xlsx")

# %% [markdown]
# # DADOS CURSOS CENSO SUPERIOR INEP
